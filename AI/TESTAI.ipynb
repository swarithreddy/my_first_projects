# %%
# !pip install numpy pandas matplotlib
# Out:
# Requirement already satisfied: numpy in c:\users\swarith reddy\appdata\local\programs\python\python312\lib\site-packages (1.26.4)
# Requirement already satisfied: pandas in c:\users\swarith reddy\appdata\local\programs\python\python312\lib\site-packages (2.2.2)
# Requirement already satisfied: matplotlib in c:\users\swarith reddy\appdata\local\programs\python\python312\lib\site-packages (3.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\swarith reddy\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\swarith reddy\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\swarith reddy\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\swarith reddy\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\swarith reddy\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\swarith reddy\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\swarith reddy\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\swarith reddy\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\swarith reddy\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\swarith reddy\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\swarith reddy\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 24.1.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python --version
# Out:
# Python 3.12.2

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("advertising.csv")

# %%
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
import seaborn as sns

# %%
sns.pairplot(df ,x_vars=["TV","Radio","Newspaper"],y_vars=["Sales"],height=4)

# %%
corr=df.corr()

# %%
corr
# Out:
#             Unnamed: 0        TV     Radio  Newspaper     Sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# Radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# Newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# Sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
x=df.drop('Sales',axis=1)

# %%
x
# Out:
#      Unnamed: 0     TV  Radio  Newspaper
# 0             1  230.1   37.8       69.2
# 1             2   44.5   39.3       45.1
# 2             3   17.2   45.9       69.3
# 3             4  151.5   41.3       58.5
# 4             5  180.8   10.8       58.4
# ..          ...    ...    ...        ...
# 195         196   38.2    3.7       13.8
# 196         197   94.2    4.9        8.1
# 197         198  177.0    9.3        6.4
# 198         199  283.6   42.0       66.2
# 199         200  232.1    8.6        8.7
#
# [200 rows x 4 columns]

# %%
y=df['Sales']

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\swarith reddy\appdata\local\programs\python\python312\lib\site-packages (1.5.0)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\swarith reddy\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\swarith reddy\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\swarith reddy\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\swarith reddy\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.5.0)
# [notice] A new release of pip is available: 24.1.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
y_hat= lr.predict(x)

# %%
y_hat
# Out:
# array([20.57251457, 12.38846299, 12.35144103, 17.64543251, 13.24052459,
#        12.51866879, 11.78301601, 12.180724  ,  3.78802522, 12.60887762,
#         7.08715353, 17.34256434, 10.61745283,  8.88300418, 18.47999068,
#        20.8606524 , 12.85204475, 23.26671246, 10.00098857, 14.2150162 ,
#        18.14231423, 14.79119255,  6.52973904, 16.59303652,  8.19342866,
#        15.65971941, 15.03489413, 17.09729941, 19.45415511,  9.18299762,
#        21.6725338 , 11.38463112,  7.68076947, 18.91087004,  7.62020678,
#        17.05319819, 23.44631521, 15.65194604,  9.94172832, 20.48118527,
#        16.41271591, 17.32707577, 21.63606281, 14.00032963,  8.91570435,
#        15.19335755,  8.9046642 , 21.75392107, 16.29149899,  8.19695581,
#        12.6626357 ,  9.37496322, 20.68673027, 19.96290112, 20.40431955,
#        21.30909879,  8.54841699, 12.80257742, 21.91749556, 18.16114677,
#         5.76901079, 22.90645956, 16.80885425, 13.23498545, 16.99561148,
#         7.87632378,  9.03979324, 12.06124085, 18.99926536, 21.1250438 ,
#        17.7944357 , 10.64412377, 10.38232525,  9.92057415, 17.34824213,
#        11.85594698,  4.4950767 , 13.82724645,  8.82756268,  9.69065949,
#        11.45762825, 14.66122134, 10.18778083, 14.4263657 , 20.78753503,
#        15.1838158 , 11.60811119, 15.5913576 , 11.70812929, 16.92002973,
#        10.01166572,  4.50260156, 19.15418328, 21.22197727, 10.49027175,
#        16.31189003, 12.64629333, 15.34104735, 24.11404042, 16.93464073,
#        13.87534134, 23.22690723, 17.64796272, 14.76413771, 20.30310486,
#        17.9238701 ,  6.12285398,  7.10840093,  3.58519686, 19.69326737,
#        14.75154529, 21.13402399, 13.88063488, 16.40113163, 15.29164402,
#        12.90360882, 11.97142784,  6.56637531, 15.54311076,  6.81008756,
#        14.39441514,  7.82030899, 13.62042032, 15.07096712, 19.43082627,
#         9.11453063, 10.5538167 ,  6.59078161, 22.2416437 ,  7.86508737,
#        10.41045195, 15.56129421,  8.43402145, 19.243822  , 11.80609249,
#        13.98077075, 11.43301748, 20.82410959,  9.74661397, 19.65590883,
#         9.46988128, 18.36443847, 19.22308369,  8.74088909, 10.06448347,
#         9.68965418, 15.27515327, 23.22779482, 12.23534643,  9.79909228,
#        18.33947913,  9.97783056, 16.33349025, 18.18926965, 15.47512722,
#         5.28059543, 15.34441549,  9.98551468, 10.34373591, 12.36435693,
#        14.17976864, 13.51709534, 14.91278707, 17.31778078, 11.03699433,
#        14.17847989, 10.78411871, 13.32973051, 17.14157897, 17.90963701,
#         7.35722248, 14.31389253,  7.56747253, 11.93459022, 13.7085193 ,
#        24.73847813, 19.93725072, 12.11868528, 15.97143167, 12.34328192,
#        10.54824625, 13.8849212 ,  6.50856493, 24.07488133, 18.49113153,
#        20.75313701,  9.6450546 , 17.02794864, 18.60146081,  6.00139443,
#        12.43794837,  8.37704275,  4.41373038, 18.43576363, 16.44377927,
#         5.32006315,  8.11608159, 12.73674753, 23.70165968, 15.12311317])
